# %%
import json
import aiohttp
import asyncio
import nest_asyncio
from typing import List

# Apply nest_asyncio to allow nested event loops in Jupyter
nest_asyncio.apply()

async def fetch_monster_json(session: aiohttp.ClientSession, monster_id: int) -> dict:
    """Fetch monster data from the API for a given ID."""
    url = f"https://api.hakush.in/zzz/data/en/monster/{monster_id}.json"
    try:
        async with session.get(url) as response:
            if response.status == 200:
                return await response.json()
            return None
    except Exception as e:
        print(f"Error fetching monster {monster_id}: {e}")
        return None

async def process_monsters():
    # First load the monster.json file to get IDs
    with open('json/monster.json', 'r', encoding='utf-8') as f:
        monster_data = json.load(f)
    
    # Extract monster IDs
    monster_ids = [int(monster_id) for monster_id in monster_data.keys()]
    
    # Create a list to store valid monster data
    processed_monsters = []
    
    async with aiohttp.ClientSession() as session:
        # Create tasks for all monster IDs
        tasks = [fetch_monster_json(session, monster_id) for monster_id in monster_ids]
        
        # Execute all tasks concurrently
        results = await asyncio.gather(*tasks)
        
        # Process results
        for monster_id, result in zip(monster_ids, results):
            if result:
                processed_monsters.append(result)
                print(f"Successfully processed monster {monster_id}")
    
    # Save processed data to a new JSON file
    with open('json/monsters_processed.json', 'w', encoding='utf-8') as f:
        json.dump(processed_monsters, f, indent=4, ensure_ascii=False)
    
    print(f"Processed {len(processed_monsters)} monsters successfully")
    return processed_monsters

# Execute the async function
monsters = asyncio.run(process_monsters())

# Display first monster as example
if monsters and len(monsters) > 0:
    print("\nExample of first monster data:")
    print(json.dumps(monsters[0], indent=2))
# Out:
# Successfully processed monster 100011
# Successfully processed monster 20012
# Successfully processed monster 200052
# Successfully processed monster 30002
# Successfully processed monster 930156
# Successfully processed monster 20005
# Successfully processed monster 100041
# Successfully processed monster 100261
# Successfully processed monster 200004
# Successfully processed monster 100004
# Successfully processed monster 200023
# Successfully processed monster 200092
# Successfully processed monster 10007
# Successfully processed monster 100151
# Successfully processed monster 20020
# Successfully processed monster 200002
# Successfully processed monster 930155
# Successfully processed monster 100131
# Successfully processed monster 300071
# Successfully processed monster 300051
# Successfully processed monster 100121
# Successfully processed monster 200151
# Successfully processed monster 200034
# Successfully processed monster 200021
# Successfully processed monster 300014
# Successfully processed monster 10012
# Successfully processed monster 200003
# Successfully processed monster 10027
# Successfully processed monster 20024
# Successfully processed monster 30004
# Successfully processed monster 20023
# Successfully processed monster 300211
# Successfully processed monster 100291
# Successfully processed monster 30023
# Successfully processed monster 100071
# Successfully processed monster 10025
# Successfully processed monster 930157
# Successfully processed monster 300012
# Successfully processed monster 300072
# Successfully processed monster 20008
# Successfully processed monster 30025
# Successfully processed monster 200015
# Successfully processed monster 100043
# Successfully processed monster 20003
# Successfully processed monster 10009
# Successfully processed monster 930149
# Successfully processed monster 930163
# Successfully processed monster 300022
# Successfully processed monster 20006
# Successfully processed monster 30032
# Successfully processed monster 30007
# Successfully processed monster 200032
# Successfully processed monster 30031
# Successfully processed monster 10023
# Successfully processed monster 200251
# Successfully processed monster 200131
# Successfully processed monster 200041
# Successfully processed monster 300021
# Successfully processed monster 930162
# Successfully processed monster 300061
# Successfully processed monster 930160
# Successfully processed monster 20015
# Successfully processed monster 200081
# Successfully processed monster 20009
# Successfully processed monster 100231
# Successfully processed monster 100111
# Successfully processed monster 200101
# Successfully processed monster 200172
# Successfully processed monster 10008
# Successfully processed monster 100021
# Successfully processed monster 30012
# Successfully processed monster 100031
# Successfully processed monster 930153
# Successfully processed monster 100161
# Successfully processed monster 10004
# Successfully processed monster 300081
# Successfully processed monster 30030
# Successfully processed monster 200121
# Successfully processed monster 20010
# Successfully processed monster 300001
# Successfully processed monster 10019
# Successfully processed monster 10000
# Successfully processed monster 100013
# Successfully processed monster 300062
# Successfully processed monster 300301
# Successfully processed monster 100141
# Successfully processed monster 300052
# Successfully processed monster 10005
# Successfully processed monster 200073
# Successfully processed monster 100301
# Successfully processed monster 30008
# Successfully processed monster 300013
# Successfully processed monster 100012
# Successfully processed monster 20017
# Successfully processed monster 10011
# Successfully processed monster 930146
# Successfully processed monster 200033
# Successfully processed monster 10001
# Successfully processed monster 30009
# Successfully processed monster 200012
# Successfully processed monster 100044
# Successfully processed monster 300004
# Successfully processed monster 10002
# Successfully processed monster 100014
# Successfully processed monster 930148
# Successfully processed monster 30018
# Successfully processed monster 200014
# Successfully processed monster 10028
# Successfully processed monster 30028
# Successfully processed monster 10006
# Successfully processed monster 100033
# Successfully processed monster 100091
# Successfully processed monster 100001
# Successfully processed monster 20025
# Successfully processed monster 200011
# Successfully processed monster 200241
# Successfully processed monster 300042
# Successfully processed monster 30006
# Successfully processed monster 300041
# Successfully processed monster 200091
# Successfully processed monster 30024
# Successfully processed monster 200071
# Successfully processed monster 20022
# Successfully processed monster 35001
# Successfully processed monster 30022
# Successfully processed monster 300082
# Successfully processed monster 10030
# Successfully processed monster 30010
# Successfully processed monster 20004
# Successfully processed monster 30011
# Successfully processed monster 930165
# Successfully processed monster 20014
# Successfully processed monster 100281
# Successfully processed monster 200053
# Successfully processed monster 200022
# Successfully processed monster 100181
# Successfully processed monster 200051
# Successfully processed monster 20002
# Successfully processed monster 200013
# Successfully processed monster 100211
# Successfully processed monster 10021
# Successfully processed monster 10018
# Successfully processed monster 200001
# Successfully processed monster 300015
# Successfully processed monster 10014
# Successfully processed monster 930150
# Successfully processed monster 930161
# Successfully processed monster 10016
# Successfully processed monster 300005
# Successfully processed monster 20007
# Successfully processed monster 30001
# Successfully processed monster 100051
# Successfully processed monster 100003
# Successfully processed monster 35002
# Successfully processed monster 100101
# Successfully processed monster 300002
# Successfully processed monster 10003
# Successfully processed monster 30017
# Successfully processed monster 100251
# Successfully processed monster 100311
# Successfully processed monster 100081
# Successfully processed monster 200171
# Successfully processed monster 30020
# Successfully processed monster 20000
# Successfully processed monster 930154
# Successfully processed monster 30016
# Successfully processed monster 930158
# Successfully processed monster 30019
# Successfully processed monster 100271
# Successfully processed monster 10031
# Successfully processed monster 930159
# Successfully processed monster 30021
# Successfully processed monster 10026
# Successfully processed monster 300003
# Successfully processed monster 30029
# Successfully processed monster 10013
# Successfully processed monster 200141
# Successfully processed monster 100032
# Successfully processed monster 100061
# Successfully processed monster 930152
# Successfully processed monster 930147
# Successfully processed monster 200061
# Successfully processed monster 10015
# Successfully processed monster 100191
# Successfully processed monster 20013
# Successfully processed monster 10020
# Successfully processed monster 30005
# Successfully processed monster 100042
# Successfully processed monster 10029
# Successfully processed monster 200072
# Successfully processed monster 200031
# Successfully processed monster 930164
# Successfully processed monster 300011
# Successfully processed monster 10010
# Successfully processed monster 100002
# Successfully processed monster 30026
# Successfully processed monster 30000
# Successfully processed monster 300121
# Successfully processed monster 20001
# Successfully processed monster 200231
# Successfully processed monster 30027
# Successfully processed monster 930151
# Processed 202 monsters successfully
#
# Example of first monster data:
# {
#   "Id": 100011,
#   "MonsterId": 11105,
#   "MonsterInfo": {
#     "CodeName": "Monster_CyclopsRed",
#     "Icon": "",
#     "Tag": [
#       "Ether",
#       "Demote",
#       "Small",
#       "Red"
#     ],
#     "Type": "Monster",
#     "Element": {
#       "Ice": 0,
#       "Fire": 1,
#       "Electric": 0,
#       "Ether": 0,
#       "Physical": 0
#     },
#     "Stats": {
#       "Hp": 1123,
#       "Attack": 54,
#       "Defence": 36,
#       "Crit": 0,
#       "CritDamage": 5000,
#       "CritRes": 0,
#       "CritDmgRes": 0,
#       "PenRate": 0,
#       "PenDelta": 0,
#       "Stun": 600,
#       "BreakStun": 0
#     },
#     "Curves": {
#       "Hp": {
#         "Curve": [
#           100,
#           116,
#           136,
#           159,
#           183,
#           200,
#           219,
#           240,
#           263,
#           303,
#           326,
#           352,
#           379,
#           409,
#           471,
#           485,
#           499,
#           514,
#           530,
#           610,
#           685,
#           770,
#           865,
#           973,
#           1119,
#           1132,
#           1146,
#           1160,
#           1174,
#           1351,
#           1411,
#           1475,
#           1541,
#           1611,
#           1853,
#           1858,
#           1864,
#           1870,
#           1876,
#           2158,
#           2228,
#           2302,
#           2377,
#           2455,
#           2824,
#           2847,
#           2872,
#           2896,
#           2920,
#           3213,
#           3293,
#           3376,
#           3460,
#           3547,
#           4080,
#           4106,
#           4132,
#           4158,
#           4185,
#           4604,
#           4637,
#           4671,
#           4705,
#           4739,
#           4774,
#           4809,
#           4844,
#           4879,
#           4915,
#           5406,
#           5406,
#           5406,
#           5406,
#           5406,
#           5406,
#           5406,
#           5406,
#           5406,
#           5406,
#           5406,
#           5406,
#           5406,
#           5406,
#           5406,
#           5406,
#           5406,
#           5406,
#           5406,
#           5406,
#           5406,
#           5406,
#           5406,
#           5406,
#           5406,
#           5406,
#           5406,
#           5406,
#           5406,
#           5406,
#           5406
#         ],
#         "Ratio": 100
#       },
#       "Attack": {
#         "Curve": [
#           100,
#           116,
#           133,
#           150,
#           167,
#           183,
#           199,
#           213,
#           227,
#           242,
#           265,
#           289,
#           312,
#           336,
#           359,
#           383,
#           406,
#           430,
#           453,
#           477,
#           496,
#           515,
#           534,
#           553,
#           573,
#           592,
#           611,
#           630,
#           649,
#           669,
#           685,
#           701,
#           717,
#           734,
#           750,
#           766,
#           783,
#           799,
#           815,
#           832,
#           846,
#           860,
#           875,
#           889,
#           904,
#           918,
#           932,
#           947,
#           961,
#           976,
#           982,
#           989,
#           995,
#           1002,
#           1009,
#           1015,
#           1022,
#           1029,
#           1035,
#           1042,
#           1049,
#           1055,
#           1062,
#           1069,
#           1075,
#           1082,
#           1089,
#           1095,
#           1102,
#           1109,
#           1109,
#           1109,
#           1109,
#           1109,
#           1109,
#           1109,
#           1109,
#           1109,
#           1109,
#           1109,
#           1109,
#           1109,
#           1109,
#           1109,
#           1109,
#           1109,
#           1109,
#           1109,
#           1109,
#           1109,
#           1109,
#           1109,
#           1109,
#           1109,
#           1109,
#           1109,
#           1109,
#           1109,
#           1109,
#           1109
#         ],
#         "Ratio": 120
#       },
#       "Defence": {
#         "Curve": [
#           100,
#           108,
#           116,
#           124,
#           132,
#           142,
#           152,
#           164,
#           176,
#           188,
#           200,
#           214,
#           228,
#           242,
#           258,
#           274,
#           290,
#           306,
#           324,
#           344,
#           362,
#           382,
#           402,
#           422,
#           444,
#           466,
#           490,
#           512,
#           536,
#           562,
#           586,
#           612,
#           638,
#           666,
#           694,
#           722,
#           750,
#           780,
#           810,
#           842,
#           872,
#           904,
#           938,
#           970,
#           1004,
#           1038,
#           1074,
#           1110,
#           1146,
#           1184,
#           1220,
#           1258,
#           1298,
#           1338,
#           1378,
#           1418,
#           1460,
#           1502,
#           1544,
#           1588,
#           1588,
#           1588,
#           1588,
#           1588,
#           1588,
#           1588,
#           1588,
#           1588,
#           1588,
#           1588,
#           1588,
#           1588,
#           1588,
#           1588,
#           1588,
#           1588,
#           1588,
#           1588,
#           1588,
#           1588,
#           1588,
#           1588,
#           1588,
#           1588,
#           1588,
#           1588,
#           1588,
#           1588,
#           1588,
#           1588,
#           1588,
#           1588,
#           1588,
#           1588,
#           1588,
#           1588,
#           1588,
#           1588,
#           1588,
#           1588
#         ],
#         "Ratio": 100
#       },
#       "Stun": {
#         "Curve": [
#           100,
#           100,
#           100,
#           100,
#           103,
#           103,
#           103,
#           103,
#           103,
#           103,
#           103,
#           104,
#           104,
#           105,
#           106,
#           106,
#           107,
#           107,
#           108,
#           109,
#           110,
#           111,
#           113,
#           114,
#           116,
#           117,
#           118,
#           120,
#           121,
#           123,
#           124,
#           125,
#           126,
#           127,
#           128,
#           129,
#           130,
#           131,
#           132,
#           134,
#           135,
#           136,
#           137,
#           139,
#           140,
#           141,
#           143,
#           144,
#           145,
#           147,
#           148,
#           149,
#           150,
#           151,
#           152,
#           153,
#           154,
#           155,
#           156,
#           157,
#           158,
#           159,
#           160,
#           161,
#           162,
#           163,
#           164,
#           165,
#           166,
#           167,
#           167,
#           167,
#           167,
#           167,
#           167,
#           167,
#           167,
#           167,
#           167,
#           167,
#           167,
#           167,
#           167,
#           167,
#           167,
#           167,
#           167,
#           167,
#           167,
#           167,
#           167,
#           167,
#           167,
#           167,
#           167,
#           167,
#           167,
#           167,
#           167,
#           167
#         ],
#         "Ratio": 100
#       }
#     }
#   },
#   "ImagePath": "UI/Sprite/A1DynamicLoad/BossCard/UnPacker/BossCardLv01/Monster_CyclopsGreyPro.png",
#   "Tag": [
#     "Ether",
#     "Pro"
#   ],
#   "Tag2": [
#     "All"
#   ],
#   "Name": "Alpeca - Energized",
#   "Desc": "The Hollow Investigative Association has limited research on Alpeca. After briefly studying its behavioral pattern of spewing liquid Ether, the Association classified Alpeca as a low-threat Ethereal and ended its investigation.\nScholars once showed great interest in observing how Alpeca spews liquefied Ether and even commissioned surveys for closer observation.\nExperienced investigators have been avoiding such tasks for unknown reasons, however.\n\"Run! They're spitting again... Oh, no! My new clothes!\"",
#   "Rarity": 1,
#   "GroupId": 201,
#   "GroupDesc": "Ether Mutants",
#   "CardObtain": "[Unidentified] Defeat this monster in Hollow Zero 1 time to obtain its data",
#   "CardQuote": "\u2014Deep within a Hollow, rookie investigator Raffaele Bert attempting to retreat",
#   "CardSkillDesc": "During combat, Alpeca will perform scattered ranged attacks."
# }

# %%
import json
import aiohttp
import asyncio
import nest_asyncio
import os
from typing import List

nest_asyncio.apply()

async def fetch_monster_json(session: aiohttp.ClientSession, monster_id: int) -> dict:
    url = f"https://api.hakush.in/zzz/data/en/monster/{monster_id}.json"
    try:
        async with session.get(url) as response:
            if response.status == 200:
                return await response.json()
            return None
    except Exception as e:
        print(f"Error fetching monster {monster_id}: {e}")
        return None

async def process_monsters():
    # Create output directory if it doesn't exist
    os.makedirs('json/monsters', exist_ok=True)
    
    # Load monster IDs
    with open('json/monster.json', 'r', encoding='utf-8') as f:
        monster_data = json.load(f)
    
    monster_ids = [int(monster_id) for monster_id in monster_data.keys()]
    processed_count = 0
    
    async with aiohttp.ClientSession() as session:
        for monster_id in monster_ids:
            result = await fetch_monster_json(session, monster_id)
            if result:
                # Save each monster to its own file
                output_file = f'json/monsters/{monster_id}.json'
                with open(output_file, 'w', encoding='utf-8') as f:
                    json.dump(result, f, indent=4, ensure_ascii=False)
                processed_count += 1
                print(f"Successfully saved monster {monster_id}")
    
    print(f"Processed and saved {processed_count} individual monster files")

# Run the async function using event loop
loop = asyncio.get_event_loop()
loop.run_until_complete(process_monsters())
# Out:
# Successfully saved monster 100011
# Successfully saved monster 20012
# Successfully saved monster 200052
# Successfully saved monster 30002
# Successfully saved monster 930156
# Successfully saved monster 20005
# Successfully saved monster 100041
# Successfully saved monster 100261
# Successfully saved monster 200004
# Successfully saved monster 100004
# Successfully saved monster 200023
# Successfully saved monster 200092
# Successfully saved monster 10007
# Successfully saved monster 100151
# Successfully saved monster 20020
# Successfully saved monster 200002
# Successfully saved monster 930155
# Successfully saved monster 100131
# Successfully saved monster 300071
# Successfully saved monster 300051
# Successfully saved monster 100121
# Successfully saved monster 200151
# Successfully saved monster 200034
# Successfully saved monster 200021
# Successfully saved monster 300014
# Successfully saved monster 10012
# Successfully saved monster 200003
# Successfully saved monster 10027
# Successfully saved monster 20024
# Successfully saved monster 30004
# Successfully saved monster 20023
# Successfully saved monster 300211
# Successfully saved monster 100291
# Successfully saved monster 30023
# Successfully saved monster 100071
# Successfully saved monster 10025
# Successfully saved monster 930157
# Successfully saved monster 300012
# Successfully saved monster 300072
# Successfully saved monster 20008
# Successfully saved monster 30025
# Successfully saved monster 200015
# Successfully saved monster 100043
# Successfully saved monster 20003
# Successfully saved monster 10009
# Successfully saved monster 930149
# Successfully saved monster 930163
# Successfully saved monster 300022
# Successfully saved monster 20006
# Successfully saved monster 30032
# Successfully saved monster 30007
# Successfully saved monster 200032
# Successfully saved monster 30031
# Successfully saved monster 10023
# Successfully saved monster 200251
# Successfully saved monster 200131
# Successfully saved monster 200041
# Successfully saved monster 300021
# Successfully saved monster 930162
# Successfully saved monster 300061
# Successfully saved monster 930160
# Successfully saved monster 20015
# Successfully saved monster 200081
# Successfully saved monster 20009
# Successfully saved monster 100231
# Successfully saved monster 100111
# Successfully saved monster 200101
# Successfully saved monster 200172
# Successfully saved monster 10008
# Successfully saved monster 100021
# Successfully saved monster 30012
# Successfully saved monster 100031
# Successfully saved monster 930153
# Successfully saved monster 100161
# Successfully saved monster 10004
# Successfully saved monster 300081
# Successfully saved monster 30030
# Successfully saved monster 200121
# Successfully saved monster 20010
# Successfully saved monster 300001
# Successfully saved monster 10019
# Successfully saved monster 10000
# Successfully saved monster 100013
# Successfully saved monster 300062
# Successfully saved monster 300301
# Successfully saved monster 100141
# Successfully saved monster 300052
# Successfully saved monster 10005
# Successfully saved monster 200073
# Successfully saved monster 100301
# Successfully saved monster 30008
# Successfully saved monster 300013
# Successfully saved monster 100012
# Successfully saved monster 20017
# Successfully saved monster 10011
# Successfully saved monster 930146
# Successfully saved monster 200033
# Successfully saved monster 10001
# Successfully saved monster 30009
# Successfully saved monster 200012
# Successfully saved monster 100044
# Successfully saved monster 300004
# Successfully saved monster 10002
# Successfully saved monster 100014
# Successfully saved monster 930148
# Successfully saved monster 30018
# Successfully saved monster 200014
# Successfully saved monster 10028
# Successfully saved monster 30028
# Successfully saved monster 10006
# Successfully saved monster 100033
# Successfully saved monster 100091
# Successfully saved monster 100001
# Successfully saved monster 20025
# Successfully saved monster 200011
# Successfully saved monster 200241
# Successfully saved monster 300042
# Successfully saved monster 30006
# Successfully saved monster 300041
# Successfully saved monster 200091
# Successfully saved monster 30024
# Successfully saved monster 200071
# Successfully saved monster 20022
# Successfully saved monster 35001
# Successfully saved monster 30022
# Successfully saved monster 300082
# Successfully saved monster 10030
# Successfully saved monster 30010
# Successfully saved monster 20004
# Successfully saved monster 30011
# Successfully saved monster 930165
# Successfully saved monster 20014
# Successfully saved monster 100281
# Successfully saved monster 200053
# Successfully saved monster 200022
# Successfully saved monster 100181
# Successfully saved monster 200051
# Successfully saved monster 20002
# Successfully saved monster 200013
# Successfully saved monster 100211
# Successfully saved monster 10021
# Successfully saved monster 10018
# Successfully saved monster 200001
# Successfully saved monster 300015
# Successfully saved monster 10014
# Successfully saved monster 930150
# Successfully saved monster 930161
# Successfully saved monster 10016
# Successfully saved monster 300005
# Successfully saved monster 20007
# Successfully saved monster 30001
# Successfully saved monster 100051
# Successfully saved monster 100003
# Successfully saved monster 35002
# Successfully saved monster 100101
# Successfully saved monster 300002
# Successfully saved monster 10003
# Successfully saved monster 30017
# Successfully saved monster 100251
# Successfully saved monster 100311
# Successfully saved monster 100081
# Successfully saved monster 200171
# Successfully saved monster 30020
# Successfully saved monster 20000
# Successfully saved monster 930154
# Successfully saved monster 30016
# Successfully saved monster 930158
# Successfully saved monster 30019
# Successfully saved monster 100271
# Successfully saved monster 10031
# Successfully saved monster 930159
# Successfully saved monster 30021
# Successfully saved monster 10026
# Successfully saved monster 300003
# Successfully saved monster 30029
# Successfully saved monster 10013
# Successfully saved monster 200141
# Successfully saved monster 100032
# Successfully saved monster 100061
# Successfully saved monster 930152
# Successfully saved monster 930147
# Successfully saved monster 200061
# Successfully saved monster 10015
# Successfully saved monster 100191
# Successfully saved monster 20013
# Successfully saved monster 10020
# Successfully saved monster 30005
# Successfully saved monster 100042
# Successfully saved monster 10029
# Successfully saved monster 200072
# Successfully saved monster 200031
# Successfully saved monster 930164
# Successfully saved monster 300011
# Successfully saved monster 10010
# Successfully saved monster 100002
# Successfully saved monster 30026
# Successfully saved monster 30000
# Successfully saved monster 300121
# Successfully saved monster 20001
# Successfully saved monster 200231
# Successfully saved monster 30027
# Successfully saved monster 930151
# Processed and saved 202 individual monster files
